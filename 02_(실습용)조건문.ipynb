# %% [markdown]
# <a href="https://colab.research.google.com/github/swKyungbock/2023Python/blob/main/02_(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%EC%A1%B0%EA%B1%B4%EB%AC%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #💕[진단평가 하러 가기](https://forms.gle/LawHNuhjZvQeEghk8)

# %% [markdown]
# # 1. 조건문 if
# * 조건식이 참(True)일 때만 특정 명령을 수행합니다.
# ![image.png](data:image/png;base64,...)
# <br>
# * <주의> 들여쓰기(기본 4칸)를 꼭 지키세요!!
# * 들여쓰기 된 만큼 수행합니다.

# %% [markdown]
# #[실습1] 배송비 안내하기
#
# *  구입 금액을 입력받아, 물건이 3만원 미만일 경우 배송비 2500원을 더해서
# 최종 결제금액을 출력하세요.

# %%
# 배송비 안내하기

# %% [markdown]
# # 2. 조건을 만드는 관계 연산자
# ![image.png](data:image/png;base64,...)
# * <주의> 대입연산자(=), 관계연산자(==)

# %% [markdown]
# #[실습2] 출결 여부를 O.X로 나타내기
#
# *   출석 혹은 결석 중 하나를 입력받고,
# *   출석을 입력했을 경우 'O' 을 출력하세요.
# *   결석을 입력했을 경우 'X' 을 출력하세요.

# %%
# 출결 여부 출력하기

# %% [markdown]
# # 3.if-else조건문
# * 조건식이 거짓(False)인 경우에도 무언가 해야 한다면 사용!
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #[실습3] 만화의 집 무인 계산기
#
#
# *   성인 요금은 15000원, 미성년자 요금은 6000원이다
# *   나이를 입력받아 성인이라면 15000원, 미성년자라면 6000원의 요금을 출력하시오.
# *   성인은 18살 이상이다.

# %%
#만화의 집 무인 계산기

# %% [markdown]
# # 4. 논리 연산자 : and, or, not
# ![image.png](data:image/png;base64,...)

# %%
#and, or, not 연산자를 각각 한 번씩 사용해 출력해 볼게요!

# %% [markdown]
# # 5. if-elif-else문
# * 조건이 여럿(3개 이상)이라면 사용하세요!
# ![image.png](data:image/png;base64,...)

# %%
#점수에 따른 학점 계산

# %% [markdown]
# #[실습4] 새백배송 조건
#
#
# *   최저 구매 금액 : 2만원
# *   5만원 미만은 배송비 2500원 추가
# *5만원 이상이면 무료 배송
#
# 구매금액을 입력받아 조건 별로 출력하기
# - '새벽배송이 불가능합니다.'
# - '배송비 2500원이 추가됩니다.'
# - '무료배송됩니다.'

# %%
#새벽배송 조건
