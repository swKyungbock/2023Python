# %% [markdown]
# <a href="https://colab.research.google.com/github/swKyungbock/2023Python/blob/main/01_(%EC%8B%A4%EC%8A%B5%EC%9A%A9)%EC%9E%85%EC%B6%9C%EB%A0%A5%2C%EB%B3%80%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. 출력 : print 함수
# ## print(출력할 내용)
# - 괄호안에있는 내용을 출력해주는 함수.
# - 문자열은 큰따옴표(")나 작은따옴표(')로 묶어줘야 함.

# %%
#Hello Python출력

# %% [markdown]
# ##1) 숫자 출력하기

# %%
#다양한 숫자 출력 : 숫자 출력, 연산자를 이용한 출력, 변수를 이용한 출력

# %% [markdown]
# ##2) 문자 출력하기

# %%
#다양한 문자 출력 : 콤마(,)를 이용한 출력, 연결자(+)를 이용한 출력, 숫자 문자의 출력

# %% [markdown]
# ## 3) 이스케이프 문자
#
# ![image.png](data:image/png;base64,...)

# %%
#이스케이프 문자를 사용하여 출력해 보기(두 줄로 된 문장의 한 줄 출력)

# %% [markdown]
# # 2.파이썬 연산자
# 연산자 우선순위 : ( ) → **  → * / // %  → + -
#
# ![image.png](data:image/png;base64,...)

# %%
#숫자 2개를 연산자를 모두 한번 씩 사용하여 연산 결과 출력해 보기

# %% [markdown]
# # 3. 입력명령어
# ## input('입력안내문')

# %%
#input()

# %%
#input('입력안내문')

# %%
#아이디와 패스워드를 입력받아보세요.

# %%
#아이와 패스워드를 기억해 볼까요?

# %%
#두 수를 입력받아 두 수의 합계를 구하여 출력해 보세요!

# %% [markdown]
# # [참고] 데이터 타입의 변환
#
#
# *   정수형 데이터로 변환 : int()
# *   실수형 데이터로 변환 : float()
# *  문자형 데이터로 변환 : str()

# %%
#두 수를 입력받아 두 수의 합계를 구하여 출력해 보세요! (데이터 타입 변환)

# %% [markdown]
# # 4. 변수
# ## 변수이름=저장할 데이터
# ![image.png](data:image/png;base64,...)

# %%
#변수 s에 '안녕'을 넣고 변수를 이용하여 출력

# %%
# '고등','대'라는 문자열과 '학생'이라는 문자열을 각각 변수에 저장하고
# 변수를 이용하여 '대학생'이라고 출력하기

# %%
#'안녕고등학생'출력하기

# %% [markdown]
# #[실습1] 과일 가격 계산하기
# * 망고🥭/사과🍎/바나나🍌의 가격은 다음과 같아요.
#   - 망고 : 15000원, 사과 : 4000원, 바나나 : 2000원
#
# * 망고, 사과, 바나나를 몇 개 구입할지 입력받아 총 구입가격을 구하세요🙂

# %%
#과일 가격 계산하기

# %% [markdown]
# #[실습2] 농구 선수의 키 예측하기
# 1년 마다 키가 10Cm씩 자라는 농구선수가 있어요!😮<br>
# 현재 연도과 키를 입력받고, 내년과 내후년의 키를 예측하여 출력해 보세요.
#
# 예)
# *   2021년 - 175.5cm
# *   2022년 - 185.5cm
# *   2023년 - 195.5cm

# %%
#농구 선수의 키 예측하기
#year(연도), height(키)
